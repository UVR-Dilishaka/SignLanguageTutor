# %%
import matplotlib.pyplot as plt

# %%
Landmark 0: x=100, y=184
Landmark 1: x=78, y=163
Landmark 2: x=58, y=137
Landmark 3: x=45, y=109
Landmark 4: x=28, y=94
Landmark 5: x=80, y=113
Landmark 6: x=72, y=75
Landmark 7: x=71, y=53
Landmark 8: x=68, y=32
Landmark 9: x=100, y=111
Landmark 10: x=95, y=70
Landmark 11: x=95, y=42
Landmark 12: x=92, y=23
Landmark 13: x=115, y=116
Landmark 14: x=117, y=77
Landmark 15: x=118, y=55
Landmark 16: x=118, y=34
Landmark 17: x=131, y=122
Landmark 18: x=138, y=96
Landmark 19: x=142, y=81
Landmark 20: x=147, y=64
# Out:
#   Cell In[2], line 1
#     Landmark 0: x=100, y=184
#              ^
# SyntaxError: invalid syntax

# %%
x1 = [100,78,58,45,28,80,72,71,68,100,95,95,92,115,117,118,118,131,138,142,147]
y1 = [184,163,137,109,94,113,75,53,32,111,70,42,23,116,77,55,34,122,96,81,64]

x2 = [99, 72, 57, 48, 35, 78, 73, 70, 69, 98, 97, 95, 93, 116, 118, 118, 117, 132, 140, 144, 147]
y2 = [175, 159, 134, 110, 97, 115, 74, 51, 34, 114, 72, 46, 28, 119, 81, 56, 38, 127, 99, 82, 67]

# %%
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.legend(['openpose', 'mediapipe']);
