# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load the dataset
data = pd.read_csv('PCA.csv')  # Update the file path if needed

# Step 2: Define features (X) and target labels (y)
X = data.drop('target', axis=1)  # Drop the target column to get features
y = data['target']  # Extract the target column as the label

# Encode target labels (convert categorical labels to integers)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# One-hot encode the target labels for NN
onehot_encoder = OneHotEncoder(sparse_output=False)
y_onehot = onehot_encoder.fit_transform(y_encoded.reshape(-1, 1))

# Step 3: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.3, random_state=42)

# Step 4: Apply PCA to reduce dimensionality
pca = PCA(n_components=0.95)  # Retain 95% of variance
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Step 5: Build the Neural Network Model
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(X_train_pca.shape[1],)),  # Use PCA-transformed features
    tf.keras.layers.Dense(64, activation='relu'),  # Hidden layer 1
    tf.keras.layers.Dense(32, activation='relu'),  # Hidden layer 2
    tf.keras.layers.Dense(y_onehot.shape[1], activation='softmax')  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Step 6: Train the Neural Network
history = model.fit(X_train_pca, y_train, epochs=50, batch_size=16, validation_split=0.2, verbose=1)

# Step 7: Evaluate the Neural Network
y_pred_probs = model.predict(X_test_pca)
y_pred = y_pred_probs.argmax(axis=1)
y_test_labels = y_test.argmax(axis=1)

accuracy_nn = accuracy_score(y_test_labels, y_pred) * 100  # Convert to percentage
print(f"Neural Network Accuracy: {accuracy_nn:.2f}%")  # Display accuracy

target_names = [str(label) for label in label_encoder.classes_]

# Generate the classification report with target names as strings
print("\nClassification Report:\n", classification_report(y_test_labels, y_pred, target_names=target_names))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred)
print("\nConfusion Matrix:\n", conf_matrix)

# Step 8: Visualize Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix (Neural Network with PCA)')
plt.show()

# Step 9: Plot Accuracy and Loss Curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0968 - loss: 2.5269 - val_accuracy: 0.1050 - val_loss: 2.4786
# Epoch 2/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1197 - loss: 2.4597 - val_accuracy: 0.1107 - val_loss: 2.4710
# Epoch 3/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1355 - loss: 2.4398 - val_accuracy: 0.1197 - val_loss: 2.4639
# Epoch 4/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1450 - loss: 2.4303 - val_accuracy: 0.1164 - val_loss: 2.4586
# Epoch 5/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1492 - loss: 2.4115 - val_accuracy: 0.1230 - val_loss: 2.4458
# Epoch 6/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1628 - loss: 2.3847 - val_accuracy: 0.1311 - val_loss: 2.4381
# Epoch 7/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1663 - loss: 2.3787 - val_accuracy: 0.1262 - val_loss: 2.4268
# Epoch 8/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1536 - loss: 2.3711 - val_accuracy: 0.1384 - val_loss: 2.4173
# Epoch 9/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1776 - loss: 2.3442 - val_accuracy: 0.1287 - val_loss: 2.4100
# Epoch 10/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1807 - loss: 2.3268 - val_accuracy: 0.1352 - val_loss: 2.3980
# Epoch 11/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1809 - loss: 2.3180 - val_accuracy: 0.1450 - val_loss: 2.3972
# Epoch 12/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2040 - loss: 2.2877 - val_accuracy: 0.1409 - val_loss: 2.3805
# Epoch 13/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2125 - loss: 2.2732 - val_accuracy: 0.1612 - val_loss: 2.3594
# Epoch 14/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2146 - loss: 2.2623 - val_accuracy: 0.1621 - val_loss: 2.3648
# Epoch 15/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2085 - loss: 2.2597 - val_accuracy: 0.1678 - val_loss: 2.3498
# Epoch 16/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2266 - loss: 2.2369 - val_accuracy: 0.1678 - val_loss: 2.3439
# Epoch 17/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2277 - loss: 2.2280 - val_accuracy: 0.1604 - val_loss: 2.3502
# Epoch 18/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2329 - loss: 2.2029 - val_accuracy: 0.1637 - val_loss: 2.3327
# Epoch 19/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2511 - loss: 2.1728 - val_accuracy: 0.1686 - val_loss: 2.3127
# Epoch 20/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2314 - loss: 2.1790 - val_accuracy: 0.1612 - val_loss: 2.3233
# Epoch 21/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2573 - loss: 2.1377 - val_accuracy: 0.1759 - val_loss: 2.3091
# Epoch 22/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2531 - loss: 2.1471 - val_accuracy: 0.1743 - val_loss: 2.3096
# Epoch 23/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2560 - loss: 2.1405 - val_accuracy: 0.1596 - val_loss: 2.3149
# Epoch 24/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2540 - loss: 2.1286 - val_accuracy: 0.1718 - val_loss: 2.2991
# Epoch 25/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2733 - loss: 2.1091 - val_accuracy: 0.1783 - val_loss: 2.2827
# Epoch 26/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2688 - loss: 2.0956 - val_accuracy: 0.1840 - val_loss: 2.2853
# Epoch 27/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2627 - loss: 2.0940 - val_accuracy: 0.1840 - val_loss: 2.2739
# Epoch 28/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2825 - loss: 2.0791 - val_accuracy: 0.1930 - val_loss: 2.2677
# Epoch 29/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2737 - loss: 2.0925 - val_accuracy: 0.1767 - val_loss: 2.2709
# Epoch 30/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2832 - loss: 2.0532 - val_accuracy: 0.1930 - val_loss: 2.2549
# Epoch 31/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2946 - loss: 2.0362 - val_accuracy: 0.1865 - val_loss: 2.2560
# Epoch 32/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2964 - loss: 2.0256 - val_accuracy: 0.1775 - val_loss: 2.2465
# Epoch 33/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2953 - loss: 2.0145 - val_accuracy: 0.1881 - val_loss: 2.2467
# Epoch 34/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3020 - loss: 2.0163 - val_accuracy: 0.1906 - val_loss: 2.2341
# Epoch 35/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3010 - loss: 2.0074 - val_accuracy: 0.1963 - val_loss: 2.2380
# Epoch 36/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3029 - loss: 1.9998 - val_accuracy: 0.1914 - val_loss: 2.2300
# Epoch 37/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3024 - loss: 2.0001 - val_accuracy: 0.1930 - val_loss: 2.2554
# Epoch 38/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3171 - loss: 1.9670 - val_accuracy: 0.1906 - val_loss: 2.2308
# Epoch 39/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3110 - loss: 1.9731 - val_accuracy: 0.1897 - val_loss: 2.2302
# Epoch 40/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3206 - loss: 1.9636 - val_accuracy: 0.1930 - val_loss: 2.2236
# Epoch 41/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3287 - loss: 1.9530 - val_accuracy: 0.1922 - val_loss: 2.2267
# Epoch 42/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3120 - loss: 1.9560 - val_accuracy: 0.2036 - val_loss: 2.2003
# Epoch 43/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3089 - loss: 1.9452 - val_accuracy: 0.2020 - val_loss: 2.2112
# Epoch 44/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3240 - loss: 1.9278 - val_accuracy: 0.2028 - val_loss: 2.2000
# Epoch 45/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3255 - loss: 1.9325 - val_accuracy: 0.2052 - val_loss: 2.2047
# Epoch 46/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3311 - loss: 1.9136 - val_accuracy: 0.1979 - val_loss: 2.1896
# Epoch 47/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3538 - loss: 1.8895 - val_accuracy: 0.2142 - val_loss: 2.1937
# Epoch 48/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3286 - loss: 1.9270 - val_accuracy: 0.2109 - val_loss: 2.2007
# Epoch 49/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3424 - loss: 1.8909 - val_accuracy: 0.2011 - val_loss: 2.2138
# Epoch 50/50
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3460 - loss: 1.8816 - val_accuracy: 0.2077 - val_loss: 2.1992
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Neural Network Accuracy: 24.37%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.38      0.47      0.42       235
#            2       0.33      0.28      0.30       234
#            3       0.23      0.12      0.16       215
#            4       0.14      0.16      0.15       210
#            5       0.14      0.09      0.11       214
#            6       0.20      0.25      0.22       183
#            7       0.24      0.11      0.15       228
#            8       0.24      0.31      0.27       209
#            9       0.25      0.34      0.29       235
#           10       0.24      0.28      0.26       231
#           11       0.23      0.27      0.25       225
#           12       0.21      0.21      0.21       211
#
#     accuracy                           0.24      2630
#    macro avg       0.24      0.24      0.23      2630
# weighted avg       0.24      0.24      0.24      2630
#
#
# Confusion Matrix:
#  [[111  23  16  20   6  12   0   9   8   8  12  10]
#  [ 40  65  14  25  16   8   7  16   9  14  11   9]
#  [ 32  25  26  24  16  20   7  22  10  14   7  12]
#  [ 21  18  14  34  21  25  17  22   9   8  11  10]
#  [ 17  21  13  33  19  34  10  21  15  17   9   5]
#  [ 12   7   9  16  12  46   9  16  28   8   8  12]
#  [ 14   4   5  22  12  20  26  28  39  28  17  13]
#  [  7  11   0  21   9  17   6  64  23  20  18  13]
#  [ 11   7   4   9   7  22   5  22  80  17  28  23]
#  [  8   4   5  15   8   9   2  19  30  65  31  35]
#  [  5   6   6  12   3  11  12  14  33  37  61  25]
#  [ 14   4   2   6   5   6   7  11  35  30  47  44]]
