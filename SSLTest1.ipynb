# %% [markdown]
# <a href="https://colab.research.google.com/github/UVR-Dilishaka/SignLanguageTutor/blob/main/SSLTest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/S_angles1n.csv')
data.tail()
# Out:
#      Image  THUMB_MCP_angle  INDEX_MCP_angle  MIDDLE_MCP_angle  \
# 1  1.2.jpg       179.764919       162.918659        164.688354
# 2  1.3.jpg       163.686400       156.874601        168.731120
# 3  1.4.jpg       164.877336       157.923103        168.825020
# 4  1.5.jpg       162.510311       155.772163        167.382585
# 5  1.6.jpg       160.702569       153.253803        166.446722
#
#    RING_MCP_angle  PINKY_MCP_angle  INDEX_PIP_angle  MIDDLE_PIP_angle  \
# 1      158.761507       150.168779       165.712954        165.773444
# 2      167.597585       155.271677       170.371422        173.189007
# 3      166.714988       154.694918       171.259425        173.170858
# 4      167.906615       151.483203       164.876201        167.474186
# 5      171.808118       154.841078       167.873037        170.454545
#
#    RING_PIP_angle  PINKY_PIP_angle  INDEX_DIP_angle  MIDDLE_DIP_angle  \
# 1      173.676437       167.715499       174.516440        176.261326
# ...

# %%
data.shape
# Out:
# (6, 18)

# %%
data['LABEL'].value_counts()
# Out:
# LABEL
# label 1    6
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Image                        6 non-null      object
#  1   THUMB_MCP_angle              6 non-null      float64
#  2   INDEX_MCP_angle              6 non-null      float64
#  3   MIDDLE_MCP_angle             6 non-null      float64
#  4   RING_MCP_angle               6 non-null      float64
#  5   PINKY_MCP_angle              6 non-null      float64
#  6   INDEX_PIP_angle              6 non-null      float64
#  7   MIDDLE_PIP_angle             6 non-null      float64
#  8   RING_PIP_angle               6 non-null      float64
#  9   PINKY_PIP_angle              6 non-null      float64
#  10  INDEX_DIP_angle              6 non-null      float64
#  11  MIDDLE_DIP_angle             6 non-null      float64
# ...

# %%
data.describe()
# Out:
#        THUMB_MCP_angle  INDEX_MCP_angle  MIDDLE_MCP_angle  RING_MCP_angle  \
# count         6.000000         6.000000          6.000000        6.000000
# mean        165.065321       158.822242        167.897703      166.201020
# std           7.512682         4.816498          2.275319        4.360989
# min         158.850393       153.253803        164.688354      158.761507
# 25%         161.154504       156.047772        166.680688      164.991727
# 50%         163.098355       157.398852        168.056852      167.156286
# 75%         164.579602       161.669770        168.801545      167.829357
# max         179.764919       166.191120        171.312416      171.808118
#
#        PINKY_MCP_angle  INDEX_PIP_angle  MIDDLE_PIP_angle  RING_PIP_angle  \
# count         6.000000         6.000000          6.000000        6.000000
# mean        153.206023       167.728004        169.802522      174.113061
# std           2.075312         2.599388          3.032986        3.329927
# ...

# %%
data.head()
# Out:
#      Image  THUMB_MCP_angle  INDEX_MCP_angle  MIDDLE_MCP_angle  \
# 0  1.1.jpg       158.850393       166.191120        171.312416
# 1  1.2.jpg       179.764919       162.918659        164.688354
# 2  1.3.jpg       163.686400       156.874601        168.731120
# 3  1.4.jpg       164.877336       157.923103        168.825020
# 4  1.5.jpg       162.510311       155.772163        167.382585
#
#    RING_MCP_angle  PINKY_MCP_angle  INDEX_PIP_angle  MIDDLE_PIP_angle  \
# 0      164.417307       152.776481       166.274985        168.753093
# 1      158.761507       150.168779       165.712954        165.773444
# 2      167.597585       155.271677       170.371422        173.189007
# 3      166.714988       154.694918       171.259425        173.170858
# 4      167.906615       151.483203       164.876201        167.474186
#
#    RING_PIP_angle  PINKY_PIP_angle  INDEX_DIP_angle  MIDDLE_DIP_angle  \
# 0      170.136228       170.599224       176.413628        177.270685
# ...

# %%
x = data.iloc[:,:-1]
x.head()
# Out:
#      Image  THUMB_MCP_angle  INDEX_MCP_angle  MIDDLE_MCP_angle  \
# 0  1.1.jpg       158.850393       166.191120        171.312416
# 1  1.2.jpg       179.764919       162.918659        164.688354
# 2  1.3.jpg       163.686400       156.874601        168.731120
# 3  1.4.jpg       164.877336       157.923103        168.825020
# 4  1.5.jpg       162.510311       155.772163        167.382585
#
#    RING_MCP_angle  PINKY_MCP_angle  INDEX_PIP_angle  MIDDLE_PIP_angle  \
# 0      164.417307       152.776481       166.274985        168.753093
# 1      158.761507       150.168779       165.712954        165.773444
# 2      167.597585       155.271677       170.371422        173.189007
# 3      166.714988       154.694918       171.259425        173.170858
# 4      167.906615       151.483203       164.876201        167.474186
#
#    RING_PIP_angle  PINKY_PIP_angle  INDEX_DIP_angle  MIDDLE_DIP_angle  \
# 0      170.136228       170.599224       176.413628        177.270685
# ...

# %%
y = data.iloc[:,-1]
y.head()
# Out:
# 0    label 1
# 1    label 1
# 2    label 1
# 3    label 1
# 4    label 1
# Name: LABEL, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x = scaler.fit_transform(x)
x[0:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-337bf52352d8> in <cell line: 1>()
# ----> 1 x = scaler.fit_transform(x)
#       2 x[0:5]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
# ...
